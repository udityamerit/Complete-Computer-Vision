# %%
import cv2 as cv
# Out:
# Running cells with 'venv (Python 3.11.14)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\Uditya\Documents\GitHub\Complete Computer Vision\venv ipykernel --update-deps --force-reinstall'

# %%
img = cv.imread('../assets/butterfly.jpg')
