# %% [markdown]
# # Module 5: Object Detection with YOLO - The State of the Art

# %% [markdown]
# ## Welcome to Module 5!
#
# In our last module, we built a CNN that could tell us *what* was in an image (e.g., "This is a T-shirt"). But what if there are multiple objects? And what if we need to know *where* they are?
#
# **Our Story for this Module:** We will take the next major leap in computer vision from **Classification** to **Object Detection**. We will learn about the revolutionary **YOLO (You Only Look Once)** family of models. Instead of building from scratch, we will use a powerful, pre-trained, state-of-the-art YOLOv8 model to detect, classify, and locate multiple objects in real-world images and videos, demonstrating the incredible power of modern deep learning.

# %% [markdown]
# ### **Setup: Installing the `ultralytics` Library**
#
# We will use the `ultralytics` library, which provides a simple, powerful Python interface for the latest YOLO models.

# %%
# %pip install -q ultralytics
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

print("Libraries imported successfully!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Uditya\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Libraries imported successfully!

# %% [markdown]
# ---

# %% [markdown]
# ## **Part 1: The Concept - What is Object Detection?**
#
# Object detection is a more advanced task than image classification.
#
# - **Image Classification:** Assigns a single label to an entire image. Answers the question: "What is in this picture?"
# - **Object Detection:** Identifies multiple objects in an image and draws a **bounding box** around each one, along with a class label and a confidence score. It answers the questions: "What objects are in this picture, where are they, and how confident am I?"

# %% [markdown]
# ### **YOLO: You Only Look Once**
#
# YOLO is a family of models that revolutionized object detection. Before YOLO, models would look at many different regions of an image separately, which was very slow.
#
# The key innovation of YOLO was to look at the entire image **just once** and predict all bounding boxes and class probabilities simultaneously. This makes it incredibly fast and suitable for real-time applications like self-driving cars and video analytics.

# %% [markdown]
# ---

# %% [markdown]
# ## **Part 2: Inference with a Pre-trained YOLOv8 Model**
#
# Training an object detection model from scratch can take days or even weeks on powerful GPUs. Instead, we will leverage **transfer learning** by using a YOLOv8 model that has already been pre-trained on the massive COCO dataset, which contains 80 common object classes (like person, car, dog, etc.).
#
# ### **2.1 Loading the Model**
#
# With the `ultralytics` library, loading a pre-trained model is as simple as a single line of code. We'll use `yolov8n.pt`, which is the smallest and fastest YOLOv8 model ('n' stands for nano).

# %%
# Load a pre-trained YOLOv8n model
print("Loading YOLOv8n model... This will download weights the first time.")
model = YOLO('yolov8n.pt')
print("Model loaded successfully!")
# Out:
# Loading YOLOv8n model... This will download weights the first time.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 284.6KB/s 22.5s2.5s<0.0s4.3s
# Model loaded successfully!

# %% [markdown]
# ### **2.2 Running Inference on an Image**
#
# Now for the "wow" moment. Let's pass an image of a busy street scene to our model and see what it finds. The `model()` call handles all the complex pre-processing and post-processing for us.

# %%
image_path = '../assets/traffic.jpg'
print(f"Running inference on '{image_path}'...")

# Run inference on the image
results = model(image_path)

# The 'results' object contains all the detection information.
# We can easily plot the results with bounding boxes.
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of results
    im = Image.fromarray(im_array[..., ::-1])  # Convert BGR to RGB

print("Inference complete. Displaying results...")
plt.figure(figsize=(12, 12))
plt.imshow(im)
plt.axis('off')
plt.show()
# Out:
# Running inference on '../assets/traffic.jpg'...
#
# image 1/1 c:\Users\Uditya\Documents\GitHub\Computer Vision\Module 5\..\assets\traffic.jpg: 640x448 1 person, 8 cars, 1 bus, 1 traffic light, 1 backpack, 1 handbag, 267.4ms
# Speed: 15.7ms preprocess, 267.4ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 448)
# Inference complete. Displaying results...

# %% [markdown]
# #### **Analysis:**
#
# Incredible! In just a few seconds, the model has correctly identified and located multiple cars, people, and even a traffic light, each with a bounding box, a label, and a confidence score.

# %% [markdown]
# ### ⭐ You Try It! - Detect Objects in Your Own Image
#
# Now it's your turn. In the cell below, **upload your own image** containing objects that the model might recognize (people, cars, animals, sports equipment, food, etc.). Then, run the inference code on your image.

# %%
# !pip install google
# Out:
# Collecting google
#   Downloading google-3.0.0-py2.py3-none-any.whl.metadata (627 bytes)
# Collecting beautifulsoup4 (from google)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->google)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\uditya\documents\github\computer vision\venv\lib\site-packages (from beautifulsoup4->google) (4.15.0)
# Using cached google-3.0.0-py2.py3-none-any.whl (45 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, google
#
#    ---------------------------------------- 0/3 [soupsieve]
#    ---------------------------------------- 0/3 [soupsieve]
#    ---------------------------------------- 0/3 [soupsieve]
#    ---------------------------------------- 0/3 [soupsieve]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [google]
#    ---------------------------------------- 3/3 [google]
#
# Successfully installed beautifulsoup4-4.14.2 google-3.0.0 soupsieve-2.8

# %%
from google.colab import files

print("Please upload your own image file.")
uploaded = files.upload()

if not uploaded:
    print("\nNo file uploaded. Please run the cell again to try.")
else:
    my_image_path = list(uploaded.keys())[0]
    print(f"\nFile '{my_image_path}' uploaded. Ready for inference.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from google.colab import files
#       3 print("Please upload your own image file.")
#       4 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
# YOUR CODE HERE: Make sure you've uploaded a file in the cell above!
if 'my_image_path' in locals():
    print(f"Running inference on your image: '{my_image_path}'...")
    my_results = model(my_image_path)

    for r in my_results:
        im_array = r.plot()
        im = Image.fromarray(im_array[..., ::-1])

    print("Inference complete on your image!")
    plt.figure(figsize=(12, 12))
    plt.imshow(im)
    plt.axis('off')
    plt.show()
else:
    print("Please run the cell above to upload an image first.")

# %% [markdown]
# ---

# %% [markdown]
# ## **Part 3: Real-Time Object Detection in Videos**
#
# Because YOLO is so fast, we can apply it to each frame of a video to perform real-time object detection.
#
# The process is simple: we'll loop through each frame of a video, run our `model()` on it, and display the resulting frame with bounding boxes. Let's try this on a video of traffic.

# %%
# This cell is for running on a local machine with a display.
# It will not display video output directly in Colab, but it processes the video.
video_path = '../assets/Social-distance.mp4'
output_path = 'output.mp4'

cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print(f"Error: Could not open video file {video_path}")
else:
    print("Processing video... This may take a few minutes.")
    # Get video properties for the writer
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Or 'XVID' for .avi
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Write the annotated frame to the output file
        out.write(annotated_frame)

    # Release everything if job is finished
    cap.release()
    out.release()
    print(f"Video processing complete. Output saved to '{output_path}'")

    # To view the video in Colab, you can use the files.download function
    from google.colab import files
    # files.download(output_path) # Uncomment to download the video
# Out:
# Processing video... This may take a few minutes.
#
# 0: 384x640 2 persons, 1 potted plant, 227.7ms
# Speed: 33.0ms preprocess, 227.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 320.4ms
# Speed: 6.1ms preprocess, 320.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 519.3ms
# Speed: 18.7ms preprocess, 519.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 381.5ms
# Speed: 9.1ms preprocess, 381.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 344.0ms
# Speed: 11.3ms preprocess, 344.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 269.2ms
# Speed: 8.4ms preprocess, 269.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 169.8ms
# Speed: 4.6ms preprocess, 169.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 171.3ms
# Speed: 6.2ms preprocess, 171.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 174.5ms
# Speed: 6.9ms preprocess, 174.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 312.9ms
# Speed: 4.3ms preprocess, 312.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 163.7ms
# Speed: 5.5ms preprocess, 163.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 162.9ms
# Speed: 5.3ms preprocess, 162.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 311.8ms
# Speed: 7.6ms preprocess, 311.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 174.3ms
# Speed: 5.2ms preprocess, 174.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 177.1ms
# Speed: 6.3ms preprocess, 177.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 261.4ms
# Speed: 5.7ms preprocess, 261.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 167.1ms
# Speed: 5.7ms preprocess, 167.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 287.7ms
# Speed: 8.1ms preprocess, 287.7ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 234.7ms
# Speed: 9.3ms preprocess, 234.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 235.7ms
# Speed: 9.7ms preprocess, 235.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 272.7ms
# Speed: 9.7ms preprocess, 272.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 220.0ms
# Speed: 13.2ms preprocess, 220.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 283.3ms
# Speed: 10.4ms preprocess, 283.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 298.7ms
# Speed: 7.6ms preprocess, 298.7ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 289.9ms
# Speed: 10.3ms preprocess, 289.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 280.3ms
# Speed: 5.9ms preprocess, 280.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 257.9ms
# Speed: 6.4ms preprocess, 257.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 270.7ms
# Speed: 17.2ms preprocess, 270.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 282.3ms
# Speed: 11.9ms preprocess, 282.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 300.1ms
# Speed: 5.7ms preprocess, 300.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 282.2ms
# Speed: 10.3ms preprocess, 282.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 252.6ms
# Speed: 10.6ms preprocess, 252.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 237.0ms
# Speed: 5.8ms preprocess, 237.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 182.7ms
# Speed: 6.2ms preprocess, 182.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 177.2ms
# Speed: 6.6ms preprocess, 177.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 1 potted plant, 161.5ms
# Speed: 7.8ms preprocess, 161.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 167.5ms
# Speed: 4.9ms preprocess, 167.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 382.7ms
# Speed: 6.3ms preprocess, 382.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 278.8ms
# Speed: 8.5ms preprocess, 278.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 263.5ms
# Speed: 11.4ms preprocess, 263.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 249.8ms
# Speed: 5.6ms preprocess, 249.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 261.7ms
# Speed: 5.6ms preprocess, 261.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 246.1ms
# Speed: 10.4ms preprocess, 246.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 258.5ms
# Speed: 6.7ms preprocess, 258.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 175.9ms
# Speed: 5.7ms preprocess, 175.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.8ms
# Speed: 5.6ms preprocess, 167.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.6ms
# Speed: 5.5ms preprocess, 167.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.6ms
# Speed: 6.0ms preprocess, 161.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.6ms
# Speed: 7.7ms preprocess, 164.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.0ms
# Speed: 64.1ms preprocess, 157.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.6ms
# Speed: 5.3ms preprocess, 162.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.2ms
# Speed: 6.5ms preprocess, 159.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 319.0ms
# Speed: 4.8ms preprocess, 319.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.5ms
# Speed: 4.8ms preprocess, 168.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.0ms
# Speed: 5.2ms preprocess, 163.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.7ms
# Speed: 4.7ms preprocess, 161.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.9ms
# Speed: 5.1ms preprocess, 167.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 176.1ms
# Speed: 5.4ms preprocess, 176.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 293.8ms
# Speed: 10.4ms preprocess, 293.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 233.4ms
# Speed: 8.2ms preprocess, 233.4ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 179.8ms
# Speed: 8.5ms preprocess, 179.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 169.6ms
# Speed: 4.8ms preprocess, 169.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 200.3ms
# Speed: 4.6ms preprocess, 200.3ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 309.0ms
# Speed: 9.2ms preprocess, 309.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 264.0ms
# Speed: 10.4ms preprocess, 264.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 247.5ms
# Speed: 7.8ms preprocess, 247.5ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 270.8ms
# Speed: 9.0ms preprocess, 270.8ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 257.9ms
# Speed: 14.3ms preprocess, 257.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 243.1ms
# Speed: 5.2ms preprocess, 243.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 268.6ms
# Speed: 16.5ms preprocess, 268.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 270.3ms
# Speed: 9.9ms preprocess, 270.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 266.2ms
# Speed: 4.9ms preprocess, 266.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 269.1ms
# Speed: 6.9ms preprocess, 269.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 283.3ms
# Speed: 6.9ms preprocess, 283.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 258.0ms
# Speed: 4.8ms preprocess, 258.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 227.5ms
# Speed: 10.4ms preprocess, 227.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 251.7ms
# Speed: 6.6ms preprocess, 251.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 172.6ms
# Speed: 8.8ms preprocess, 172.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 195.6ms
# Speed: 5.0ms preprocess, 195.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 191.3ms
# Speed: 6.4ms preprocess, 191.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 227.3ms
# Speed: 7.7ms preprocess, 227.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 190.0ms
# Speed: 5.5ms preprocess, 190.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 197.2ms
# Speed: 56.9ms preprocess, 197.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 225.9ms
# Speed: 5.3ms preprocess, 225.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 201.7ms
# Speed: 6.7ms preprocess, 201.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 430.4ms
# Speed: 7.3ms preprocess, 430.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 434.7ms
# Speed: 7.8ms preprocess, 434.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 353.2ms
# Speed: 12.5ms preprocess, 353.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 242.8ms
# Speed: 7.6ms preprocess, 242.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 270.0ms
# Speed: 5.2ms preprocess, 270.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 266.9ms
# Speed: 5.4ms preprocess, 266.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 251.3ms
# Speed: 4.9ms preprocess, 251.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 250.2ms
# Speed: 7.9ms preprocess, 250.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 258.0ms
# Speed: 5.4ms preprocess, 258.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 344.8ms
# Speed: 9.2ms preprocess, 344.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 492.4ms
# Speed: 4.7ms preprocess, 492.4ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 480.2ms
# Speed: 6.8ms preprocess, 480.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.8ms
# Speed: 4.9ms preprocess, 155.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 186.0ms
# Speed: 6.8ms preprocess, 186.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 179.7ms
# Speed: 5.0ms preprocess, 179.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 340.0ms
# Speed: 5.0ms preprocess, 340.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 283.0ms
# Speed: 10.9ms preprocess, 283.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 434.4ms
# Speed: 6.8ms preprocess, 434.4ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 482.7ms
# Speed: 12.3ms preprocess, 482.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 803.7ms
# Speed: 34.4ms preprocess, 803.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 267.9ms
# Speed: 5.4ms preprocess, 267.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 379.1ms
# Speed: 7.5ms preprocess, 379.1ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 302.2ms
# Speed: 14.8ms preprocess, 302.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 187.1ms
# Speed: 5.4ms preprocess, 187.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 216.5ms
# Speed: 5.3ms preprocess, 216.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 199.4ms
# Speed: 4.9ms preprocess, 199.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 236.8ms
# Speed: 5.7ms preprocess, 236.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 199.8ms
# Speed: 10.3ms preprocess, 199.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 233.6ms
# Speed: 6.5ms preprocess, 233.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 337.4ms
# Speed: 9.5ms preprocess, 337.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 177.3ms
# Speed: 4.5ms preprocess, 177.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 328.0ms
# Speed: 5.0ms preprocess, 328.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 175.3ms
# Speed: 4.6ms preprocess, 175.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.3ms
# Speed: 4.5ms preprocess, 167.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 183.6ms
# Speed: 6.0ms preprocess, 183.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 178.8ms
# Speed: 5.2ms preprocess, 178.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 212.0ms
# Speed: 4.8ms preprocess, 212.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 208.3ms
# Speed: 5.4ms preprocess, 208.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 198.7ms
# Speed: 4.9ms preprocess, 198.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 174.1ms
# Speed: 4.7ms preprocess, 174.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 431.2ms
# Speed: 4.7ms preprocess, 431.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 457.3ms
# Speed: 7.2ms preprocess, 457.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 313.6ms
# Speed: 17.6ms preprocess, 313.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 183.2ms
# Speed: 4.9ms preprocess, 183.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 180.7ms
# Speed: 4.7ms preprocess, 180.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 191.4ms
# Speed: 5.2ms preprocess, 191.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 385.9ms
# Speed: 5.4ms preprocess, 385.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 190.9ms
# Speed: 4.1ms preprocess, 190.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 potted plant, 211.7ms
# Speed: 5.3ms preprocess, 211.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 245.8ms
# Speed: 6.0ms preprocess, 245.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 295.3ms
# Speed: 7.8ms preprocess, 295.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 245.5ms
# Speed: 5.7ms preprocess, 245.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 450.1ms
# Speed: 4.8ms preprocess, 450.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 461.0ms
# Speed: 9.3ms preprocess, 461.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 429.4ms
# Speed: 6.3ms preprocess, 429.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 208.5ms
# Speed: 6.6ms preprocess, 208.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 278.8ms
# Speed: 4.7ms preprocess, 278.8ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 258.4ms
# Speed: 4.8ms preprocess, 258.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 397.8ms
# Speed: 4.5ms preprocess, 397.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 253.6ms
# Speed: 5.1ms preprocess, 253.6ms inference, 11.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 275.5ms
# Speed: 8.5ms preprocess, 275.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 185.3ms
# Speed: 5.0ms preprocess, 185.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 283.8ms
# Speed: 6.5ms preprocess, 283.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 195.1ms
# Speed: 4.7ms preprocess, 195.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 184.1ms
# Speed: 4.5ms preprocess, 184.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 199.1ms
# Speed: 5.0ms preprocess, 199.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 194.7ms
# Speed: 4.9ms preprocess, 194.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 171.2ms
# Speed: 4.8ms preprocess, 171.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 335.7ms
# Speed: 4.1ms preprocess, 335.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 289.3ms
# Speed: 4.7ms preprocess, 289.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 176.9ms
# Speed: 5.4ms preprocess, 176.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 183.7ms
# Speed: 4.6ms preprocess, 183.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 182.3ms
# Speed: 4.6ms preprocess, 182.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.4ms
# Speed: 6.0ms preprocess, 163.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.6ms
# Speed: 4.9ms preprocess, 163.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 208.0ms
# Speed: 5.2ms preprocess, 208.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.8ms
# Speed: 4.6ms preprocess, 166.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 199.4ms
# Speed: 4.7ms preprocess, 199.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 187.6ms
# Speed: 5.6ms preprocess, 187.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 173.7ms
# Speed: 5.6ms preprocess, 173.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 174.4ms
# Speed: 5.0ms preprocess, 174.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 185.1ms
# Speed: 4.7ms preprocess, 185.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.8ms
# Speed: 4.7ms preprocess, 165.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 171.8ms
# Speed: 4.4ms preprocess, 171.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 184.6ms
# Speed: 4.9ms preprocess, 184.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 177.9ms
# Speed: 5.4ms preprocess, 177.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 237.7ms
# Speed: 4.6ms preprocess, 237.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 202.7ms
# Speed: 4.9ms preprocess, 202.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 168.1ms
# Speed: 4.7ms preprocess, 168.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 210.8ms
# Speed: 4.9ms preprocess, 210.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 179.1ms
# Speed: 5.4ms preprocess, 179.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 212.8ms
# Speed: 4.5ms preprocess, 212.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 178.5ms
# Speed: 4.8ms preprocess, 178.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.2ms
# Speed: 4.9ms preprocess, 153.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.3ms
# Speed: 4.9ms preprocess, 147.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 143.9ms
# Speed: 6.0ms preprocess, 143.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 148.4ms
# Speed: 4.9ms preprocess, 148.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.3ms
# Speed: 4.6ms preprocess, 147.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 142.0ms
# Speed: 4.6ms preprocess, 142.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 144.5ms
# Speed: 4.8ms preprocess, 144.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 142.8ms
# Speed: 4.7ms preprocess, 142.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 remote, 137.4ms
# Speed: 5.4ms preprocess, 137.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 remote, 143.2ms
# Speed: 5.0ms preprocess, 143.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.7ms
# Speed: 4.6ms preprocess, 166.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 150.4ms
# Speed: 4.9ms preprocess, 150.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 148.5ms
# Speed: 5.0ms preprocess, 148.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 149.3ms
# Speed: 5.5ms preprocess, 149.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 277.6ms
# Speed: 5.4ms preprocess, 277.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 247.2ms
# Speed: 6.2ms preprocess, 247.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 148.2ms
# Speed: 5.5ms preprocess, 148.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 150.1ms
# Speed: 5.2ms preprocess, 150.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 149.9ms
# Speed: 4.7ms preprocess, 149.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 146.0ms
# Speed: 4.8ms preprocess, 146.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 146.2ms
# Speed: 4.9ms preprocess, 146.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 149.7ms
# Speed: 5.3ms preprocess, 149.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 142.3ms
# Speed: 5.0ms preprocess, 142.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.2ms
# Speed: 4.7ms preprocess, 147.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 142.7ms
# Speed: 4.6ms preprocess, 142.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 145.7ms
# Speed: 4.7ms preprocess, 145.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 131.7ms
# Speed: 4.5ms preprocess, 131.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 145.8ms
# Speed: 5.8ms preprocess, 145.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 143.2ms
# Speed: 4.5ms preprocess, 143.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 140.1ms
# Speed: 5.0ms preprocess, 140.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 138.2ms
# Speed: 4.8ms preprocess, 138.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 145.9ms
# Speed: 4.6ms preprocess, 145.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 150.8ms
# Speed: 4.8ms preprocess, 150.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 139.0ms
# Speed: 4.3ms preprocess, 139.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 139.9ms
# Speed: 5.2ms preprocess, 139.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 148.0ms
# Speed: 5.8ms preprocess, 148.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 190.3ms
# Speed: 4.8ms preprocess, 190.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 141.1ms
# Speed: 4.5ms preprocess, 141.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 143.7ms
# Speed: 5.0ms preprocess, 143.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 141.6ms
# Speed: 4.6ms preprocess, 141.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 135.7ms
# Speed: 4.7ms preprocess, 135.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 143.0ms
# Speed: 4.7ms preprocess, 143.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 141.9ms
# Speed: 5.1ms preprocess, 141.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 139.1ms
# Speed: 5.0ms preprocess, 139.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 140.2ms
# Speed: 5.8ms preprocess, 140.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 140.1ms
# Speed: 5.0ms preprocess, 140.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 139.9ms
# Speed: 4.5ms preprocess, 139.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.2ms
# Speed: 4.4ms preprocess, 153.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 199.7ms
# Speed: 4.7ms preprocess, 199.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 204.7ms
# Speed: 4.7ms preprocess, 204.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 207.0ms
# Speed: 4.6ms preprocess, 207.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 186.8ms
# Speed: 4.5ms preprocess, 186.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.7ms
# Speed: 26.7ms preprocess, 162.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.9ms
# Speed: 4.5ms preprocess, 155.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 199.1ms
# Speed: 4.6ms preprocess, 199.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 194.6ms
# Speed: 4.5ms preprocess, 194.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.6ms
# Speed: 5.0ms preprocess, 158.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 201.6ms
# Speed: 4.5ms preprocess, 201.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.1ms
# Speed: 5.1ms preprocess, 156.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 206.1ms
# Speed: 5.1ms preprocess, 206.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.6ms
# Speed: 4.9ms preprocess, 157.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.7ms
# Speed: 5.3ms preprocess, 153.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.5ms
# Speed: 4.6ms preprocess, 154.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.4ms
# Speed: 4.5ms preprocess, 154.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.7ms
# Speed: 4.6ms preprocess, 157.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.8ms
# Speed: 8.6ms preprocess, 156.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.4ms
# Speed: 4.5ms preprocess, 158.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.5ms
# Speed: 4.5ms preprocess, 157.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.2ms
# Speed: 5.1ms preprocess, 157.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.6ms
# Speed: 4.6ms preprocess, 152.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.7ms
# Speed: 4.9ms preprocess, 159.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.9ms
# Speed: 5.2ms preprocess, 154.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 181.5ms
# Speed: 4.6ms preprocess, 181.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.7ms
# Speed: 4.5ms preprocess, 151.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.2ms
# Speed: 5.3ms preprocess, 158.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 212.5ms
# Speed: 4.4ms preprocess, 212.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.0ms
# Speed: 4.4ms preprocess, 151.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.8ms
# Speed: 5.2ms preprocess, 160.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.3ms
# Speed: 4.6ms preprocess, 151.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.3ms
# Speed: 4.6ms preprocess, 153.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.6ms
# Speed: 5.1ms preprocess, 158.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.3ms
# Speed: 4.8ms preprocess, 154.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.8ms
# Speed: 4.5ms preprocess, 153.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.3ms
# Speed: 4.7ms preprocess, 152.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 150.3ms
# Speed: 4.6ms preprocess, 150.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 147.8ms
# Speed: 4.9ms preprocess, 147.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.0ms
# Speed: 4.8ms preprocess, 156.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.5ms
# Speed: 4.7ms preprocess, 152.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 216.4ms
# Speed: 4.5ms preprocess, 216.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.4ms
# Speed: 5.3ms preprocess, 152.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.3ms
# Speed: 5.0ms preprocess, 158.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 208.1ms
# Speed: 4.6ms preprocess, 208.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.7ms
# Speed: 4.4ms preprocess, 164.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 235.7ms
# Speed: 5.2ms preprocess, 235.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 210.9ms
# Speed: 4.5ms preprocess, 210.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 177.8ms
# Speed: 5.0ms preprocess, 177.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.0ms
# Speed: 4.4ms preprocess, 155.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.4ms
# Speed: 4.8ms preprocess, 166.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.2ms
# Speed: 5.0ms preprocess, 154.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.4ms
# Speed: 4.6ms preprocess, 156.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.3ms
# Speed: 4.8ms preprocess, 153.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.1ms
# Speed: 4.6ms preprocess, 152.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.6ms
# Speed: 5.1ms preprocess, 157.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.0ms
# Speed: 4.7ms preprocess, 155.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.3ms
# Speed: 4.4ms preprocess, 160.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.9ms
# Speed: 4.6ms preprocess, 159.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.7ms
# Speed: 4.6ms preprocess, 157.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.6ms
# Speed: 4.9ms preprocess, 162.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 194.9ms
# Speed: 4.2ms preprocess, 194.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.2ms
# Speed: 4.4ms preprocess, 151.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.8ms
# Speed: 4.8ms preprocess, 155.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.3ms
# Speed: 4.6ms preprocess, 151.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.0ms
# Speed: 4.5ms preprocess, 159.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 177.7ms
# Speed: 5.5ms preprocess, 177.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 150.8ms
# Speed: 5.0ms preprocess, 150.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.6ms
# Speed: 4.5ms preprocess, 155.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.8ms
# Speed: 4.4ms preprocess, 159.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 170.3ms
# Speed: 4.8ms preprocess, 170.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.5ms
# Speed: 5.1ms preprocess, 160.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.4ms
# Speed: 4.6ms preprocess, 153.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 243.2ms
# Speed: 4.6ms preprocess, 243.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.9ms
# Speed: 5.0ms preprocess, 153.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.0ms
# Speed: 4.8ms preprocess, 156.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.2ms
# Speed: 4.3ms preprocess, 159.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 207.5ms
# Speed: 4.4ms preprocess, 207.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.1ms
# Speed: 4.6ms preprocess, 154.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 169.6ms
# Speed: 4.6ms preprocess, 169.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 169.4ms
# Speed: 4.5ms preprocess, 169.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.0ms
# Speed: 4.9ms preprocess, 159.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.8ms
# Speed: 4.5ms preprocess, 164.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.9ms
# Speed: 4.1ms preprocess, 166.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.7ms
# Speed: 4.6ms preprocess, 157.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.0ms
# Speed: 4.5ms preprocess, 166.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 153.2ms
# Speed: 4.3ms preprocess, 153.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 148.9ms
# Speed: 4.5ms preprocess, 148.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.7ms
# Speed: 4.6ms preprocess, 165.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.0ms
# Speed: 5.1ms preprocess, 156.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.4ms
# Speed: 5.1ms preprocess, 155.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.8ms
# Speed: 5.2ms preprocess, 152.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 204.7ms
# Speed: 4.8ms preprocess, 204.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.4ms
# Speed: 4.8ms preprocess, 156.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.7ms
# Speed: 7.0ms preprocess, 154.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.4ms
# Speed: 5.5ms preprocess, 154.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.6ms
# Speed: 5.1ms preprocess, 158.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 151.5ms
# Speed: 4.9ms preprocess, 151.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.5ms
# Speed: 4.6ms preprocess, 154.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.9ms
# Speed: 5.1ms preprocess, 161.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.0ms
# Speed: 4.5ms preprocess, 156.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.5ms
# Speed: 4.6ms preprocess, 167.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 172.6ms
# Speed: 4.8ms preprocess, 172.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 198.5ms
# Speed: 4.7ms preprocess, 198.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 183.8ms
# Speed: 5.3ms preprocess, 183.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 174.9ms
# Speed: 4.6ms preprocess, 174.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 233.4ms
# Speed: 5.3ms preprocess, 233.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 310.1ms
# Speed: 4.8ms preprocess, 310.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 298.6ms
# Speed: 15.4ms preprocess, 298.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 202.9ms
# Speed: 6.3ms preprocess, 202.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 195.8ms
# Speed: 4.9ms preprocess, 195.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 262.8ms
# Speed: 4.8ms preprocess, 262.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1167.7ms
# Speed: 7.4ms preprocess, 1167.7ms inference, 97.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 826.6ms
# Speed: 219.2ms preprocess, 826.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 476.8ms
# Speed: 7.7ms preprocess, 476.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 217.9ms
# Speed: 7.2ms preprocess, 217.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 248.3ms
# Speed: 5.6ms preprocess, 248.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 202.3ms
# Speed: 5.1ms preprocess, 202.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Video processing complete. Output saved to 'output.mp4'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 40
#      37 print(f"Video processing complete. Output saved to '{output_path}'")
#      39 # To view the video in Colab, you can use the files.download function
# ---> 40 from google.colab import files
#      41 # files.download(output_path) # Uncomment to download the video
#
# ModuleNotFoundError: No module named 'google'

# %%
from IPython.display import HTML
from base64 import b64encode

# Try to play the video in Colab
try:
    mp4 = open(output_path, 'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
    display(HTML(f'<video width=600 controls><source src="{data_url}" type="video/mp4"></video>'))
    print("\nVideo displayed successfully.")
except Exception as e:
    print(f"\nCould not display video in Colab: {e}")
    print(f"You can download the video using the code below:")
    from google.colab import files
    files.download(output_path)

# %% [markdown]
# ### ⭐ You Try It! - your own video
#
# Pre-trained models, such as those provided by Ultralytics, are often trained on large, general-purpose datasets like COCO (Common Objects in Context). This allows them to detect a diverse set of common objects, including:
# People and vehicles: pedestrians, cars, trucks, bicycles, motorcycles, buses.
# Animals: cats, dogs, birds, horses, sheep, cows, elephants, bears, zebras, giraffes.
# Household items: chairs, tables, couches, televisions, laptops, keyboards, cell phones, books, clocks, vases, bowls, cups.
# Food items: apples, oranges, bananas, pizzas, hot dogs, cakes.
# Sports equipment: sports balls, bats, gloves, skis, snowboards.

# %%
# please write a code to process your own video file

# %% [markdown]
# ## **Conclusion**
#
# Congratulations! You've just used a state-of-the-art deep learning model to perform a complex computer vision task.
#
# We've learned:
# 1.  The difference between **Image Classification** and **Object Detection**.
# 2.  The core idea behind the **YOLO** family of models that makes them so fast and effective.
# 3.  How to use the `ultralytics` library to load a pre-trained **YOLOv8** model and run inference on both images and videos with just a few lines of code.
#
# This module demonstrates the power of transfer learning and the incredible capabilities of modern, pre-trained models. While training these models is a massive undertaking, using them is becoming easier and more accessible every day.
#
# **In our next module,** we'll explore another exciting, high-level application: using **MediaPipe** for real-time human pose and landmark detection.
